# %% [markdown]
# <a href="https://colab.research.google.com/github/nitingithub12/BTECH_PROJECT/blob/main/chanceofadmission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
school=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Admission%20Chance.csv')
school.head()
# Out:
#    Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0          1        337          118                  4   4.5   4.5  9.65
# 1          2        324          107                  4   4.0   4.5  8.87
# 2          3        316          104                  3   3.0   3.5  8.00
# 3          4        322          110                  3   3.5   2.5  8.67
# 4          5        314          103                  2   2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No          400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4    SOP               400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
school.describe()
# Out:
#         Serial No   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
school.columns
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
y=school['Chance of Admit ']
x=school[['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
       'LOR ', 'CGPA', 'Research']]

# %%
from sklearn.model_selection import train_test_split

# Assuming 'salary' is a pandas DataFrame containing 'Salary' and 'Experience Years' columns
y=school['Chance of Admit ']
x=school[['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
       'LOR ', 'CGPA', 'Research']]
# Split the data into training and testing sets with stratification
# The error is likely due to a single unique value in 'y'
# Check for unique values in 'y' and handle accordingly
# For example, if there are only a few unique values, you might consider removing the stratify parameter
# If there are many unique values, you might consider removing the rows with the single occurrence
# Alternatively, you could try a different splitting method that doesn't rely on stratification
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=2529)

# %%
from sklearn.linear_model import LinearRegression

# Create a linear regression model
model = LinearRegression()

# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -1.3491869284562994

# %%
model.coef_
# Out:
# array([ 0.00018075,  0.00217672,  0.00396487,  0.00836627, -0.00080004,
#         0.02030329,  0.09551552,  0.01979659])

# %%
y_pre=model.predict(X_test)

# %%
X_test
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 244        245        314          107                  2   2.5   4.0  8.56
# 366        367        320          104                  3   3.5   4.5  8.34
# 163        164        317          105                  3   3.5   3.0  8.56
# 379        380        311           99                  1   2.5   3.0  8.43
# 182        183        299          100                  2   3.0   3.5  7.88
# ..         ...        ...          ...                ...   ...   ...   ...
# 26          27        322          109                  5   4.5   3.5  8.80
# 252        253        318          100                  2   2.5   3.5  8.54
# 208        209        305          106                  2   3.0   3.0  8.16
# 211        212        328          110                  4   5.0   4.0  9.14
# 86          87        315          106                  3   4.5   3.5  8.42
#
#      Research
# 244         0
# 366         1
# ...

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test, y_pre)  #(100 %-ERROR PERCENTAGE)=ACCURACY  100- 7 =93 % ACCURACY
# Out:
# 0.07400437276133896
