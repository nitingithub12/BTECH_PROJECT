# %% [markdown]
# <a href="https://colab.research.google.com/github/nitingithub12/BTECH_PROJECT/blob/main/placementprediction18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
placement=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Placement.csv')
placement.head()
# Out:
#    Student_ID  CGPA   IQ  Placement
# 0           1   6.8  123          1
# 1           2   5.9  106          0
# 2           3   5.3  121          0
# 3           4   7.4  132          1
# 4           5   5.8  142          0

# %%
placement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  100 non-null    int64
#  1   CGPA        100 non-null    float64
#  2   IQ          100 non-null    int64
#  3   Placement   100 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 KB

# %%
placement.describe()
# Out:
#        Student_ID        CGPA          IQ   Placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      1.000000    3.300000   37.000000    0.000000
# 25%     25.750000    5.075000  101.500000    0.000000
# 50%     50.500000    6.000000  127.500000    0.500000
# 75%     75.250000    6.900000  149.000000    1.000000
# max    100.000000    8.500000  233.000000    1.000000

# %%
placement.columns
# Out:
# Index(['Student_ID', 'CGPA', 'IQ', 'Placement'], dtype='object')

# %%
y=placement['Placement']
x=placement[['Student_ID', 'CGPA', 'IQ']]

# %%
from sklearn.model_selection import train_test_split

# Assuming 'salary' is a pandas DataFrame containing 'Salary' and 'Experience Years' columns
y=placement['Placement']
x=placement[['Student_ID', 'CGPA', 'IQ']]



# Split the data into training and testing sets with stratification
# The error is likely due to a single unique value in 'y'
# Check for unique values in 'y' and handle accordingly
# For example, if there are only a few unique values, you might consider removing the stratify parameter
# If there are many unique values, you might consider removing the rows with the single occurrence
# Alternatively, you could try a different splitting method that doesn't rely on stratification
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=2529)

# %%
from sklearn.tree import DecisionTreeClassifier

# Create a linear regression model
model = DecisionTreeClassifier()
# Train the model on the training data
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pre=model.predict(X_test)

# %%
X_test
# Out:
#     Student_ID  CGPA   IQ
# 93          94   6.8  112
# 9           10   5.1   66
# 82          83   6.5   37
# 81          82   5.4  107
# 27          28   6.0  124
# 45          46   6.0   66
# 44          45   7.5   61
# 63          64   6.3  128
# 69          70   8.5  120
# 76          77   4.9  155
# 6            7   5.7  143
# 21          22   7.1  151
# 38          39   6.5  160
# 39          40   4.6  146
# 98          99   6.3  103
# 79          80   6.5   90
# 70          71   6.3  127
# 89          90   4.9  151
# 4            5   5.8  142
# 12          13   5.4  139
# 46          47   5.3  114
# 53          54   8.3  168
# 3            4   7.4  132
# 66          67   6.9   96
# 26          27   7.0  199
# 73          74   4.9   61
# 34          35   4.8  163
# 99         100   6.2  113
# 28          29   5.2   90
# 20          21   6.6  120

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pre)
# Out:
# 0.9333333333333333
